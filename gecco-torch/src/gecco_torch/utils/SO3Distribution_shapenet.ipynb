# %%
# %load_ext autoreload
# %autoreload 2

# %%
import jax.numpy as jnp
import jaxlie
import numpy as np
from gecco_torch.utils.isotropic_plotting import visualize_so3_probabilities, visualize_so3_density
from gecco_torch.scene.gaussian_model import GaussianModel
# Out:
# /home/giese/miniconda3/envs/gecco/lib/python3.10/site-packages/jaxtyping/__init__.py:243: UserWarning: jaxtyping version >=0.2.23 should be used with Equinox version >=0.11.1
#   warnings.warn(

# %%
def vis(cat,ins):
    gc = GaussianModel(3)
    gc.load_ply(f"/globalwork/giese/gaussians/{cat}/{ins}/point_cloud/iteration_10000/point_cloud.ply")
    
    rotations_plane = gc.get_rotation.detach() # quats in wxyz
    # speichere sie für so3diffusion models
    np.save("/home/giese/Documents/SO3DiffusionModels/rotations_plane.npy", rotations_plane.cpu().numpy())
    # bringe sie in xyzw, weil das ist womit lietorch später arbeitet
    rotations_plane = rotations_plane[:,[1,2,3,0]]
    # Create a checkerboard grid
    visualize_so3_probabilities(
        jnp.array([jaxlie.SO3(x[[3,0,1,2]].cpu().numpy()).as_matrix() for x in rotations_plane]),
        0.001);

# %% [markdown]
# ## visualize plane rotation distribution

# %%
vis("02691156","1a04e3eab45ca15dd86060f189eb133")
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# /home/giese/Documents/gecco/gecco-torch/src/gecco_torch/utils/isotropic_plotting.py:102: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([r'90$\degree$', None,

# %%
gc = GaussianModel(3)
gc.load_ply(f"/globalwork/giese/gaussians/02691156/1a04e3eab45ca15dd86060f189eb133/point_cloud/iteration_10000/point_cloud.ply")

rotations_plane = gc.get_rotation.detach() # quats in wxyz
# bringe sie in xyzw, weil das ist womit lietorch später arbeitet
rotations_plane = rotations_plane[:,[1,2,3,0]]
# Create a checkerboard grid
visualize_so3_density(
    jnp.array([jaxlie.SO3(x[[3,0,1,2]].cpu().numpy()).as_matrix() for x in rotations_plane]),
    32);

# %%
vis("02691156","1a6ad7a24bb89733f412783097373bdc")
# Out:
# /home/giese/Documents/gecco/gecco-torch/src/gecco_torch/utils/isotropic_plotting.py:102: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([r'90$\degree$', None,

# %%
vis("02691156","1a9b552befd6306cc8f2d5fe7449af61")
# Out:
# /home/giese/Documents/gecco/gecco-torch/src/gecco_torch/utils/isotropic_plotting.py:102: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([r'90$\degree$', None,

# %%
vis("02691156","1a32f10b20170883663e90eaf6b4ca52")
# Out:
# /home/giese/Documents/gecco/gecco-torch/src/gecco_torch/utils/isotropic_plotting.py:102: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([r'90$\degree$', None,

# %% [markdown]
# ## Visualize car rotation

# %%
vis("02958343","19c25429d34ce9748c844a5e3a5e1a93")
# Out:
# /home/giese/Documents/gecco/gecco-torch/src/gecco_torch/utils/isotropic_plotting.py:102: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([r'90$\degree$', None,

# %% [markdown]
# ## Visualize bench rotation

# %%
vis("02828884","1a40eaf5919b1b3f3eaa2b95b99dae6")
# Out:
# /home/giese/Documents/gecco/gecco-torch/src/gecco_torch/utils/isotropic_plotting.py:102: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([r'90$\degree$', None,

# %% [markdown]
# ## Visualize chair rotation

# %%
vis("03001627","1a6f615e8b1b5ae4dbbc9440457e303e")
# Out:
# /home/giese/Documents/gecco/gecco-torch/src/gecco_torch/utils/isotropic_plotting.py:102: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([r'90$\degree$', None,

# %% [markdown]
# ## Visualize pots rotation

# %%
vis("03593526","1a01c2d7705193b4917cb569753af492")
# Out:
# /home/giese/Documents/gecco/gecco-torch/src/gecco_torch/utils/isotropic_plotting.py:102: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([r'90$\degree$', None,

# %% [markdown]
# ## Visualize lamps rotation

# %%
vis("03636649","1a5ebc8575a4e5edcc901650bbbbb0b5")
# Out:
# /home/giese/Documents/gecco/gecco-torch/src/gecco_torch/utils/isotropic_plotting.py:102: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([r'90$\degree$', None,

# %% [markdown]
# ## Visualize pots 2 rotation

# %%
vis("03991062","1a1a0794670a2114d6bef0ac9b3a5962")
# Out:
# /home/giese/Documents/gecco/gecco-torch/src/gecco_torch/utils/isotropic_plotting.py:102: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([r'90$\degree$', None,

# %% [markdown]
# ## Visualize rifles rotation

# %%
vis("04090263","1a6aab87fdd90323d810dcd63f342aca")
# Out:
# /home/giese/Documents/gecco/gecco-torch/src/gecco_torch/utils/isotropic_plotting.py:102: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([r'90$\degree$', None,

# %% [markdown]
# ## Visualize sofa rotation

# %%
vis("04256520","1a4a8592046253ab5ff61a3a2a0e2484")
# Out:
# /home/giese/Documents/gecco/gecco-torch/src/gecco_torch/utils/isotropic_plotting.py:102: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([r'90$\degree$', None,

# %% [markdown]
# ## Visualize table rotation

# %%
vis("04379243","1a00aa6b75362cc5b324368d54a7416f")
# Out:
# /home/giese/Documents/gecco/gecco-torch/src/gecco_torch/utils/isotropic_plotting.py:102: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([r'90$\degree$', None,

# %% [markdown]
# ## Visualize ship rotations

# %%
vis("04530566","1a2b1863733c2ca65e26ee427f1e5a4c")
# Out:
# /home/giese/Documents/gecco/gecco-torch/src/gecco_torch/utils/isotropic_plotting.py:102: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([r'90$\degree$', None,
