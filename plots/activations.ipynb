# %%
from gecco_torch.scene.gaussian_model import GaussianModel
import numpy as np
gm = GaussianModel(3)
gm.load_ply("/globalwork/giese/gaussians/02691156/1a04e3eab45ca15dd86060f189eb133/point_cloud/iteration_10000/point_cloud.ply")

# %%
gm.get_opacity.sum()/gm.get_opacity.shape[0]
# Out:
# tensor(0.9767, device='cuda:0', grad_fn=<DivBackward0>)

# %%
import matplotlib.pyplot as plt
plt.hist(gm.get_opacity.detach().cpu().numpy(), bins=np.arange(0.75,1,0.01))
# Out:
# (array([ 4.,  4.,  3.,  2.,  3.,  5.,  6.,  3.,  3.,  5.,  4.,  4.,  8.,
#         11., 11.,  7.,  6., 13.,  8., 10.,  9., 15., 22., 39.]),
#  array([0.75, 0.76, 0.77, 0.78, 0.79, 0.8 , 0.81, 0.82, 0.83, 0.84, 0.85,
#         0.86, 0.87, 0.88, 0.89, 0.9 , 0.91, 0.92, 0.93, 0.94, 0.95, 0.96,
#         0.97, 0.98, 0.99]),
#  <BarContainer object of 24 artists>)
